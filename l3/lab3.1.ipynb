# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pl
# %matplotlib inline

# %%
from keras import models, layers
from sklearn.model_selection import train_test_split

# %%
infa = pd.read_csv('diabetes.csv')
infa
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
y = infa['Outcome']
x = infa.drop(['Outcome'], axis = 1)

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
scaler = StandardScaler()
xscaled = scaler.fit_transform(x)
xtrain, xtest, ytrain, ytest =train_test_split(xscaled, y, test_size = 0.2)

# %%
madel = models.Sequential([
    layers.Dense(units = 16, activation = 'relu', input_shape = (8, )), 
    layers.Dense(units = 16, activation = 'relu'),
    layers.Dense(units = 1, activation = 'sigmoid')
])
madel.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 16)                144
#
#  dense_7 (Dense)             (None, 16)                272
#
#  dense_8 (Dense)             (None, 1)                 17
#
# ...
# Total params: 433
# Trainable params: 433
# Non-trainable params: 0
# _________________________________________________________________

# %%
madel.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
madel.fit(xtrain, ytrain, epochs=64, batch_size= 32, validation_data=(xtest,ytest),verbose=2)
# Out:
# Epoch 1/64
# 20/20 - 0s - loss: 0.4240 - accuracy: 0.8127 - val_loss: 0.4825 - val_accuracy: 0.7468 - 142ms/epoch - 7ms/step
# Epoch 2/64
# 20/20 - 0s - loss: 0.4216 - accuracy: 0.8111 - val_loss: 0.4864 - val_accuracy: 0.7338 - 72ms/epoch - 4ms/step
# Epoch 3/64
# 20/20 - 0s - loss: 0.4198 - accuracy: 0.8143 - val_loss: 0.4869 - val_accuracy: 0.7338 - 72ms/epoch - 4ms/step
# Epoch 4/64
# 20/20 - 0s - loss: 0.4196 - accuracy: 0.8127 - val_loss: 0.4858 - val_accuracy: 0.7273 - 85ms/epoch - 4ms/step
# Epoch 5/64
# 20/20 - 0s - loss: 0.4178 - accuracy: 0.8143 - val_loss: 0.4815 - val_accuracy: 0.7338 - 71ms/epoch - 4ms/step
# Epoch 6/64
# 20/20 - 0s - loss: 0.4166 - accuracy: 0.8160 - val_loss: 0.4811 - val_accuracy: 0.7338 - 87ms/epoch - 4ms/step
# Epoch 7/64
# 20/20 - 0s - loss: 0.4164 - accuracy: 0.8143 - val_loss: 0.4853 - val_accuracy: 0.7273 - 79ms/epoch - 4ms/step
# Epoch 8/64
# ...
